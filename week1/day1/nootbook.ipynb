# %% [markdown]
# day 1 in traning

# %% [markdown]
# **setup the Environment**
#
#
# I have initialized the Python environment and installed the necessary libraries via the terminal. I proactively addressed and resolved various installation challenges, ensuring a stable and reproducible environment for this project.

# %% [markdown]
# **Virtual Environment Setup**
#
#
# I set up a venv to create an isolated environment for this project. This approach ensures that all necessary libraries are properly managed and that the environment is reproducible, allowing others to easily set up and execute the code after me.

# %% [markdown]
# to create

# %%
python -m venv .venv

# %% [markdown]
# to activate

# %%
.\.venv\Scripts\activate

# %% [markdown]
# to download

# %%
pip install pandas numpy jupyter

# %% [markdown]
# to save it

# %%
pip freeze > requirements.txt
