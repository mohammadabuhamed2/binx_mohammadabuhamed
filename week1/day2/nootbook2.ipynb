# %% [markdown]
# ***day 2 hands-on lab***

# %% [markdown]
# 1-defining the function and the max and min
#
# 2- the for loop to find the min and the max
#
# 3- to save it in a dict

# %%
#1
def MaxAndMin(numbers):
    max=numbers[0]
    min=numbers[0]
    #2
    for i in numbers:
        if i>max:
            max=i
        if i<min:
            min=i
 #3
    MinMax={
        "max":max,
        "Min":min
    }
    return MinMax
    
l=[1,2,3,4,5,6,7,8,9]
print(MaxAndMin(l))

# %% [markdown]
# to Rewrite a given for-loop as a single list comprehension

# %%
def EvenNumbers(numbers):
    ll=[i for i in numbers if i%2==0]
    print(ll)
    EvenNumbers(l)

# %% [markdown]
# bilud a class with tow attributes and one method

# %%
class student:
    def __init__(self,name,id,status):
        self.name=name
        self.id=id
        self.status=status
    def IsActive(self):
        if self.status==True:
            return True
        else:
            return False
        
    
ss=student("mohammad",1212,True)
print(ss.IsActive())
