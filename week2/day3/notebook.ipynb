# %% [markdown]
# ***day 3 week 2 in training***

# %% [markdown]
# ***1-create 3xfitutres***
#
# first column age
#
# second column experince
#
# third column salary
#
# shape (3,3)

# %%
import numpy as np
employees=np.array([
    [22,3,5000],
    [26,5,8000],
    [28,10,15000]
]
)

# %% [markdown]
# ***2-create vector and do dot with one sapmle***

# %%
weight=np.array([0.5,2,0.002])
res=np.dot(weight,employees[0])
print(res)
# Out:
# 27.0

# %% [markdown]
# 22x0.5=11
#
# 2x3=6
#
# 5000x0.002=10
#
# 11+6+10=27

# %% [markdown]
# ***3-do @ on all matrix***
#
# (3,3).(3,)valid

# %%
res2=employees@weight
print(res2)
# Out:
# [27. 39. 64.]

# %% [markdown]
# ***4- make erorr and fix it***

# %%
weightE=np.array([1,2])
res3=employees@weightE
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 weightE=np.array([1,2])
# ----> 2 res3=employees@weightE
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 3)

# %% [markdown]
# *the erorr in tha shape (3,3).(2,) not valid to fix it we need to add one more weight for last index*

# %%
weightE=np.array([1,2,3])
res3=employees@weightE
print(res3)
# Out:
# [15028 24036 45048]
